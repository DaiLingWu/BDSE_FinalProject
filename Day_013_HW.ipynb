# %%
import numpy as np
import pandas as pd
csv_path='/Users/wudailing/Downloads/application_train.csv'

# %%
train=pd.read_csv(csv_path)

# %%
train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %% [markdown]
# <h1>Subset

# %%
train_0=train[train['CNT_CHILDREN']==0]

# %%
train_0.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#               ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
train_1=train[train['CNT_CHILDREN']==1]

# %%
train_1.head()
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 6       100009       0         Cash loans           F            Y
# 10      100014       0         Cash loans           F            N
# 13      100017       0         Cash loans           M            Y
# 17      100021       0    Revolving loans           F            N
# 19      100023       0         Cash loans           F            N
#
#    FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 6                Y             1          171000.0   1560726.0      41301.0
# 10               Y             1          112500.0    652500.0      21177.0
# 13               N             1          225000.0    918468.0      28966.5
# 17               Y             1           81000.0    270000.0      13500.0
# 19               Y             1           90000.0    544491.0      17563.5
#
#                ...              FLAG_DOCUMENT_18 FLAG_DOCUMENT_19  \
# ...

# %%
cut_rule=[0,2,3,5]
groupname=['0-2個小孩','3-5個小孩','5個小孩以上']

# %%
train['CNT_CHILDREN_GROUP'] = pd.cut(train['CNT_CHILDREN'].values, cut_rule, include_lowest=True,labels=groupname)

# %%
train.head()
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
#           ...          FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# ...

# %%
train['CNT_CHILDREN_GROUP'].value_counts()
# Out:
# 0-2個小孩    303239
# 3-5個小孩      3717
# 5個小孩以上       513
# Name: CNT_CHILDREN_GROUP, dtype: int64

# %%
train.groupby(['CNT_CHILDREN_GROUP'])['TARGET'].hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-90-79d22a46ba7d> in <module>()
#       1 train.groupby(['CNT_CHILDREN_GROUP'])['TARGET'].hist()
# ----> 2 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %%
train.groupby(['CNT_CHILDREN_GROUP'])['AMT_INCOME_TOTAL'].mean()
# Out:
# CNT_CHILDREN_GROUP
# 0-2個小孩    168733.459246
# 3-5個小孩    173948.262712
# 5個小孩以上    171293.508772
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
train.groupby(['TARGET'])['AMT_INCOME_TOTAL'].mean()
# Out:
# TARGET
# 0    169077.722266
# 1    165611.760906
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
mean=train['AMT_INCOME_TOTAL'].mean()
SD=train['AMT_INCOME_TOTAL'].std()

# %%
Z_score=(train['AMT_INCOME_TOTAL']-mean)/SD

# %%
Z_score
# Out:
# 0         0.142129
# 1         0.426791
# 2        -0.427195
# 3        -0.142533
# 4        -0.199466
# 5        -0.294353
# 6         0.009287
# 7         0.806341
# 8        -0.237421
# 9        -0.142533
# 10       -0.237421
# 11       -0.549836
# 12       -0.427195
# 13        0.237016
# 14        0.085197
# 15       -0.047646
# 16       -0.256398
# 17       -0.370263
# 18       -0.237421
# 19       -0.332308
# 20       -0.142533
# 21        0.142129
# 22        1.185890
# 23       -0.360774
# 24       -0.142533
# 25       -0.332308
# 26       -0.237421
# 27       -0.237421
# 28        0.426791
# 29       -0.332308
#             ...
# 307481    0.237016
# 307482    0.237016
# 307483   -0.294353
# 307484    1.565440
# 307485    0.426791
# 307486    0.521679
# 307487   -0.218443
# 307488   -0.047646
# 307489    0.237016
# 307490   -0.370263
# 307491   -0.332308
# 307492    1.755215
# 307493   -0.142533
# 307494    0.426791
# 307495    0.047242
# 307496    0.806341
# ...
